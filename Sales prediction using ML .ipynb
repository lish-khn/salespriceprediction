# %% [markdown]
# # Alisha Khan

# %% [markdown]
# # Sales price prediction Using Python M

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib as plt

# %%
df = pd.read_csv(r"C:\Users\FUJITSU\OneDrive\Desktop\Data analysis\Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.isna()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# - Highest spend on TV and lowest on Radio
# - max sale is 18.5 and min is 12.9

# %%
sns.pairplot(df, x_vars = ["TV","Radio","Newspaper"], y_vars="Sales", kind="scatter")

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['TV']], df[['Sales']], test_size = 0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
res= model.predict(X_test)
print(res)
# Out:
# [[10.48116264]
#  [ 9.60152727]
#  [11.4524267 ]
#  [20.58322509]
#  [15.1084112 ]
#  [ 9.8855762 ]
#  [ 7.70939494]
#  [18.31083372]
#  [ 8.40119151]
#  [16.36372418]
#  [19.28209777]
#  [11.3058208 ]
#  [14.48533615]
#  [15.91474363]
#  [10.81102591]
#  [12.81769409]
#  [19.47909945]
#  [ 7.3428802 ]
#  [10.73314153]
#  [17.08759078]
#  [20.48701497]
#  [13.73856237]
#  [15.33290148]
#  [13.34455903]
#  [ 9.76187747]
#  [12.95055569]
#  [14.89766523]
#  [16.70275031]
#  [17.57322281]
#  [ 8.46075015]
#  [10.41702256]
#  [16.42328282]
#  [20.17089601]
#  [18.38413667]
#  [ 7.91555948]
#  [ 8.16753836]
#  [10.04134496]
#  [15.59404323]
#  [10.44451117]
#  [ 8.45616872]
#  [ 9.00135939]
#  [ 8.75396194]
#  [13.85767966]
#  [16.91349628]
#  [17.17921947]
#  [12.01594311]
#  [ 7.70481351]
#  [ 8.08507255]
#  [13.06967298]
#  [12.10299036]
#  [12.34122494]
#  [17.82520169]
#  [18.93849021]
#  [15.78188203]
#  [ 9.35871126]
#  [10.16504368]
#  [20.72983099]
#  [15.21378419]
# ...

# %%
print(X_test)
# Out:
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# 63   102.7
# 8      8.6
# 75    16.9
# 118  125.7
# 143  104.6
# 71   109.8
# 124  229.5
# 184  253.8
# 97   184.9
# 149   44.7
# 24    62.3
# 30   292.9
# 160  172.5
# 40   202.5
# 56     7.3

# %%
model.coef_
# Out:
# array([[0.04581434]])

# %%
model.intercept_
# Out:
# array([7.31081017])

# %%
69.2*0.04581434 + 7.31081017
# Out:
# 10.481162498

# %% [markdown]
# # Hence, The model is predicing values correctly!
